# %%
#1

# %%
valor1 = int(input('Digite um numero inteiro:'))

# %%
valor2 = int(input('digite outro numero inteiro:'))

# %%
valorR = float(input('digite agora um numero real:'))

# %%
#a)
print(( valor1 * 2 ) * (valor2 / 2))
# Out:
# 170.0

# %%
#b)
print((valor1 * 3) + (valorR ** 3))
# Out:
# 33.375

# %%
#2

# %%
valor3 = float(input('digite um numero:'))

# %%
valor4 = float(input('digite outro numero:'))

# %%
if valor3 > valor4:
    print("o valor ",valor3," é maior que o valor ",valor4)
else:
    print("o valor ",valor4," é maior que o valor ",valor3)
# Out:
# o valor  10.0  é maior que o valor  5.0

# %%
#3

# %%
valor5 = int(input("digite outro numero:"))

# %%
if valor5 < 0:
    print("O numero ",valor5," é negativo")
else:
    print("O numero ",valor5," é positivo")
# Out:
# O numero  2  é positivo

# %%
#4

# %%
valor6 = float(input("digite a primeira nota: "))

# %%
valor7 = float(input("digite a segunda nota: "))

# %%
media = (valor6+valor7)/2

# %%
if media<7:
    print("reprovado")
else:
    print("aprovado")
# Out:
# aprovado

# %%
#5

# %%
valor8 = int(input("digite um numero: "))

# %%
valor9 = int(input("digite outro valor: "))

# %%
valor10 = int(input("digite mais um valor: "))

# %%
if valor8 > valor9 & valor8 > valor10:
    print("O valor ",valor8," é o maior de todos")
elif valor9 > valor8 & valor9 > valor10:
    print("O valor ",valor9," é o maior de todos")
else:
    print("O valor ",valor10," é o maior de todos")
# Out:
# O valor  9  é o maior de todos
